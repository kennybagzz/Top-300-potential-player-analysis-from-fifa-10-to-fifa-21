# %%
import pandas as pd
import numpy as np

fifa_year = input("What fifa year do you want to analyze? ")

player_dataset = pd.read_csv(f'fifa_{fifa_year}_top300_potential_players.csv')
player_dataset
# Out:
# What fifa year do you want to analyze? 10
#               Player name          Known as  player_id position nationality  \
# 0            Lionel Messi          L. Messi     158023   ['RW']   Argentina
# 1          Alexandre Pato    Alexandre Pato     180175   ['CF']      Brazil
# 2                   Bojan             Bojan     176993   ['CF']       Spain
# 3             Hugo Lloris         H. Lloris     167948   ['GK']      France
# 4          Yoann Gourcuff       Y. Gourcuff     153296  ['CAM']      France
# ..                    ...               ...        ...      ...         ...
# 295      Bruno Pereirinha  Bruno Pereirinha     176031   ['RM']    Portugal
# 296  Kevin Prince Boateng        K. Boateng     173909   ['CM']     Germany
# 297                Adrian            Adrian     173818   ['ST']       Spain
# 298          Mark Randall        M. Randall     173538   ['CM']     England
# 299     Sebastien Bassong        S. Bassong     172949   ['CB']      France
#
# ...
